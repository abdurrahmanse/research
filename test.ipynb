# %%
# Out:
#   Cell In[2], line 1
#     chmod 600 ~/.kaggle/kaggle.json
#           ^
# SyntaxError: invalid syntax

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
import os

# Authenticate
api = KaggleApi()
api.authenticate()

# Download dataset (replace with your dataset reference)
dataset_name = 'username/dataset-name'  # e.g., 'zalando-research/fashionmnist'
download_path = './data'

api.dataset_download_files(dataset_name, path=download_path, unzip=True)
print(f"Dataset downloaded to {download_path}")
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/abdurrahman/.kaggle/kaggle.json'
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/abdurrahman/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/username/dataset-name
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 12
#       9 dataset_name = 'username/dataset-name'  # e.g., 'zalando-research/fashionmnist'
#      10 download_path = './data'
# ---> 12 api.dataset_download_files(dataset_name, path=download_path, unzip=True)
#      13 print(f"Dataset downloaded to {download_path}")
#
# File /opt/anaconda3/lib/python3.13/site-packages/kaggle/api/kaggle_api_extended.py:2214, in KaggleApi.dataset_download_files(self, dataset, path, force, quiet, unzip, licenses)
#    2212     request.dataset_slug = dataset_slug
#    2213     request.dataset_version_number = int(dataset_version_number) if dataset_version_number else None
# -> 2214     response = kaggle.datasets.dataset_api_client.download_dataset(request)
#    2216 outfile = os.path.join(effective_path, dataset_slug + ".zip")
#    2217 if force or self.download_needed(response, outfile, quiet):
#
# File /opt/anaconda3/lib/python3.13/site-packages/kagglesdk/datasets/services/dataset_api_service.py:93, in DatasetApiClient.download_dataset(self, request)
#      90 if request is None:
#      91   request = ApiDownloadDatasetRequest()
# ---> 93 return self._client.call("datasets.DatasetApiService", "DownloadDataset", request, HttpRedirect)
#
# File /opt/anaconda3/lib/python3.13/site-packages/kagglesdk/kaggle_http_client.py:98, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#      94     settings["stream"] = True
#      96 http_response = self._session.send(http_request, **settings)
# ---> 98 response = self._prepare_response(response_type, http_response)
#      99 return response
#
# File /opt/anaconda3/lib/python3.13/site-packages/kagglesdk/kaggle_http_client.py:124, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     122 except KeyError:
#     123     pass
# --> 124 http_response.raise_for_status()
#     125 # Allow client to check header content.
#     126 if self._response_processor:
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/DownloadDataset

# %%
import pandas as pd
from kaggle.api.kaggle_api_extended import KaggleApi

# Setup
api = KaggleApi()
api.authenticate()

# Download
dataset_name = 'your-dataset-name'
download_path = './data'
api.dataset_download_files(dataset_name, path=download_path, unzip=True)

# Load and use
df = pd.read_csv(f'{download_path}/your_file.csv')
print(df.head())
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/abdurrahman/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/abdurrahmansoftw/your-dataset-name
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       9 dataset_name = 'your-dataset-name'
#      10 download_path = './data'
# ---> 11 api.dataset_download_files(dataset_name, path=download_path, unzip=True)
#      13 # Load and use
#      14 df = pd.read_csv(f'{download_path}/your_file.csv')
#
# File /opt/anaconda3/lib/python3.13/site-packages/kaggle/api/kaggle_api_extended.py:2214, in KaggleApi.dataset_download_files(self, dataset, path, force, quiet, unzip, licenses)
#    2212     request.dataset_slug = dataset_slug
#    2213     request.dataset_version_number = int(dataset_version_number) if dataset_version_number else None
# -> 2214     response = kaggle.datasets.dataset_api_client.download_dataset(request)
#    2216 outfile = os.path.join(effective_path, dataset_slug + ".zip")
#    2217 if force or self.download_needed(response, outfile, quiet):
#
# File /opt/anaconda3/lib/python3.13/site-packages/kagglesdk/datasets/services/dataset_api_service.py:93, in DatasetApiClient.download_dataset(self, request)
#      90 if request is None:
#      91   request = ApiDownloadDatasetRequest()
# ---> 93 return self._client.call("datasets.DatasetApiService", "DownloadDataset", request, HttpRedirect)
#
# File /opt/anaconda3/lib/python3.13/site-packages/kagglesdk/kaggle_http_client.py:98, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#      94     settings["stream"] = True
#      96 http_response = self._session.send(http_request, **settings)
# ---> 98 response = self._prepare_response(response_type, http_response)
#      99 return response
#
# File /opt/anaconda3/lib/python3.13/site-packages/kagglesdk/kaggle_http_client.py:124, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     122 except KeyError:
#     123     pass
# --> 124 http_response.raise_for_status()
#     125 # Allow client to check header content.
#     126 if self._response_processor:
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/DownloadDataset
