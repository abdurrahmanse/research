# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in /opt/anaconda3/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (1.5.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (1.17.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (2.3.3)
# Requirement already satisfied: matplotlib>=3.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (3.10.8)
# Requirement already satisfied: pydantic>=1.8.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (2.12.5)
# Requirement already satisfied: PyYAML>=5.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (3.1.6)
# Requirement already satisfied: visions==0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (0.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (2.4.2)
# Requirement already satisfied: htmlmin>=0.1.12 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (0.12.5)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (0.1.0)
# Requirement already satisfied: requests>=2.24.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (2.32.5)
# Requirement already satisfied: tqdm>=4.48.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (4.67.3)
# Requirement already satisfied: seaborn>=0.10.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /opt/anaconda3/lib/python3.13/site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling) (3.6.1)
# Requirement already satisfied: bottleneck in /opt/anaconda3/lib/python3.13/site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling) (1.4.2)
# Requirement already satisfied: multimethod==1.4 in /opt/anaconda3/lib/python3.13/site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling) (1.4)
# Requirement already satisfied: imagehash in /opt/anaconda3/lib/python3.13/site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (4.3.2)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.13/site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (12.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2>=2.11.1->pandas-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.2.0->pandas-profiling) (25.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=1.8.1->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=1.8.1->pandas-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=1.8.1->pandas-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=1.8.1->pandas-profiling) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.24.0->pandas-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.24.0->pandas-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.24.0->pandas-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.24.0->pandas-profiling) (2026.2.25)
# Requirement already satisfied: PyWavelets in /opt/anaconda3/lib/python3.13/site-packages (from imagehash->visions[type_image_path]==0.7.1->pandas-profiling) (1.9.0)

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas_profiling/__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas_profiling/controller/pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)     15         A ProfileReport of the DataFrame.
#      16     """
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas_profiling/profile_report.py:11
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#
# File /opt/anaconda3/lib/python3.13/site-packages/visions/__init__.py:3
#       1 """Core functionality"""
# ----> 3 from visions import types, typesets, utils
#       4 from visions.backends import *
#       5 from visions.declarative import create_type
#
# File /opt/anaconda3/lib/python3.13/site-packages/visions/utils/__init__.py:4
#       1 """ Utilities suite for visions """
#       3 # from visions.utils.images import image_utils
# ----> 4 from visions.utils.monkeypatches import imghdr_patch, pathlib_patch
#       5 from visions.utils.profiling import profile_type
#       6 from visions.utils.warning_handling import suppress_warnings
#
# File /opt/anaconda3/lib/python3.13/site-packages/visions/utils/monkeypatches/__init__.py:1
# ----> 1 from visions.utils.monkeypatches import imghdr_patch, pathlib_patch
#       3 __all__ = [
#       4     "imghdr_patch",
#       5     "pathlib_patch",
#       6 ]
#
# File /opt/anaconda3/lib/python3.13/site-packages/visions/utils/monkeypatches/imghdr_patch.py:2
#       1 # Monkeypatch bug in imagehdr
# ----> 2 from imghdr import tests
#       5 def test_jpeg1(h, f):
#       6     """JPEG data in JFIF format"""
#
# ModuleNotFoundError: No module named 'imghdr'
